# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import requests
import json
import xml.etree.ElementTree as ET
from tqdm import tqdm

# %%
API_KEY = '6a7ae5ce3e4037d4f907b4eba7cf496ea6cbeb83'
report_codes =['11011','11012','11013','11014']
years = ['2022','2021','2020','2019','2018'] 
corp_code = '00266961'

# %%
naver_rpt_data = pd.DataFrame()
for year in tqdm(years):
    for code in report_codes:
        financial_statement_url = f'https://opendart.fss.or.kr/api/fnlttSinglAcnt.json?crtfc_key={API_KEY}&corp_code=00266961&bsns_year=2022&reprt_code={code}'
        response = requests.get(financial_statement_url)
        response = json.loads(response.text)
        if response.get('list') != None:
            temp = pd.DataFrame(response.get('list'))
            naver_rpt_data = naver_rpt_data.append(temp)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.71it/s]

# %%
naver_rpt_data
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20220816002164      11012      2022  00266961     035420    CFS  연결재무제표
# 1   20220816002164      11012      2022  00266961     035420    CFS  연결재무제표
# 2   20220816002164      11012      2022  00266961     035420    CFS  연결재무제표
# 3   20220816002164      11012      2022  00266961     035420    CFS  연결재무제표
# 4   20220816002164      11012      2022  00266961     035420    CFS  연결재무제표
# ..             ...        ...       ...       ...        ...    ...     ...
# 21  20221114002234      11014      2022  00266961     035420    OFS    재무제표
# 22  20221114002234      11014      2022  00266961     035420    OFS    재무제표
# 23  20221114002234      11014      2022  00266961     035420    OFS    재무제표
# 24  20221114002234      11014      2022  00266961     035420    OFS    재무제표
# 25  20221114002234      11014      2022  00266961     035420    OFS    재무제표
#
# ...
