# %% [markdown]
# # 네이버 기사 크롤링

# %% [markdown]
# ### import

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# ### 기사 제목과 url

# %%
respone = requests.get(
    "https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=020&date=20230110",
    headers={
        'User-Agent': 'Mozilla 5.0'
    }
)
bs = BeautifulSoup(respone.text, 'lxml')

# %%
urls_and_titles = bs.select(".list_body.newsflash_body > ul dt > a")
urls_and_titles
# Out:
# [<a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473040">
#  <img alt="현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473040.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473040">
#  								 현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473039">
#  <img alt="아웃백 품은 bhc그룹, ‘매출 1조’ 클럽 입성… “2030년 3조 원 목표”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473039.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473039">
#  								 아웃백 품은 bhc그룹, ‘매출 1조’ 클럽 입성… “2030년 3조 원 목표”
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473038">
#  <img alt="지구에 희소식…“오존층 점점 회복…2040년이면 1980년대 수준으로”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473038.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473038">
#  								 지구에 희소식…“오존층 점점 회복…2040년이면 1980년대 수준으로”
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473037">
#  <img alt="기아, ‘경차 모닝’ 할부 부담 완화… 한국은행 기준금리 적용" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473037.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473037">
#  								 기아, ‘경차 모닝’ 할부 부담 완화… 한국은행 기준금리 적용
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473036">
#  <img alt="檢출석 이재명, “쫄았냐”는 시민에 ‘쉿’…날 선 신경전" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473036.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473036">
#  								 檢출석 이재명, “쫄았냐”는 시민에 ‘쉿’…날 선 신경전
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473035">
#  <img alt="서울 초6·중3 ‘기초학력 보장 채움학기’ 운영…학습부진 해소" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473035.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473035">
#  								 서울 초6·중3 ‘기초학력 보장 채움학기’ 운영…학습부진 해소
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473034">
#  <img alt="불륜설 휘말린 UN 최정원 “말도 안 돼…가족도 알고 지낸 동생”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473034.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473034">
#  								 불륜설 휘말린 UN 최정원 “말도 안 돼…가족도 알고 지낸 동생”
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473033">
#  <img alt="대법, ‘스토킹 살인’ 김병찬 징역 40년 확정" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473033.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473033">
#  								 대법, ‘스토킹 살인’ 김병찬 징역 40년 확정
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473032">
#  <img alt="청년 고용 한파…고용보험 가입자수 넉달째 감소" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473032.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473032">
#  								 청년 고용 한파…고용보험 가입자수 넉달째 감소
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473031">
#  <img alt="SKT, 오픈랜 가상화 기지국 국내 첫 상용망 실증" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473031.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473031">
#  								 SKT, 오픈랜 가상화 기지국 국내 첫 상용망 실증
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473030">
#  <img alt="31년 만에 30대 신부가 더 많아졌다…20대 신부 수 추월" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473030.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473030">
#  								 31년 만에 30대 신부가 더 많아졌다…20대 신부 수 추월
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473029">
#  								 현대차, 계묘년 맞이 ‘MobED와 B.B.래빗의 신비로운 여행’ 전시
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473028">
#  <img alt="이재명 檢출석…“李 지키자” “구속하라” 1100여명 찬반 집회" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473028.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473028">
#  								 이재명 檢출석…“李 지키자” “구속하라” 1100여명 찬반 집회
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473027">
#  <img alt="中, 한국인 단기비자 발급 전격중단…입국규제 보복" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473027.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473027">
#  								 中, 한국인 단기비자 발급 전격중단…입국규제 보복
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473026">
#  <img alt="손흥민의 동료였던 개러스 베일 은퇴…베일 “내 인생 최고의 순간이었다”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473026.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473026">
#  								 손흥민의 동료였던 개러스 베일 은퇴…베일 “내 인생 최고의 순간이었다”
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473025">
#  <img alt="나경원, 尹에 저출산委 부위원장직 사의 표명" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473025.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473025">
#  								 나경원, 尹에 저출산委 부위원장직 사의 표명
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473024">
#  <img alt="운동에 식단 더한다… 현대그린푸드, 커브스코리아와 업무협약" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473024.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473024">
#  								 운동에 식단 더한다… 현대그린푸드, 커브스코리아와 업무협약
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473023">
#  <img alt="“김만배, 권순일에 ‘언론사 회장직’ 제안”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473023.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473023">
#  								 “김만배, 권순일에 ‘언론사 회장직’ 제안”
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473022">
#  <img alt="“가스배관 타고 망봐주고” 교도소 동기끼리 빈집 털다 붙잡혀" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473022.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473022">
#  								 “가스배관 타고 망봐주고” 교도소 동기끼리 빈집 털다 붙잡혀
#  								</a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473021">
#  <img alt="넥슨의 2023년 첫 신작 '나이트 워커' 어떤 게임일까?" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/020/2023/01/10/3473021.jpg?type=nf106_72" width="106"/>
#  </a>,
#  <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/020/0003473021">
#  								 넥슨의 2023년 첫 신작 '나이트 워커' 어떤 게임일까?
#  								</a>]

# %%
title = urls_and_titles[1].text.strip()
url = urls_and_titles[1].get("href").strip()
title
# Out:
# '현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해'

# %%
print(f"{title} : {url}")
# Out:
# 현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해 : https://n.news.naver.com/mnews/article/020/0003473040

# %% [markdown]
# ### 기사 본문

# %%
respone = requests.get('https://n.news.naver.com/mnews/article/020/0003473040', 
    headers={
        'User-Agent': 'Mozilla 5.0'
    }
)
bs = BeautifulSoup(respone.text,"lxml")
#bs
#content = bs.select("#dic_area")[0].text.strip()
#content
# Out:
# <!DOCTYPE html>
# <html data-useragent="Mozilla 5.0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/020/0003473040" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/020/2023/01/10/0003473040_001_20230110150802674.jpg?type=w800" property="og:image"/>
# <meta content="현대자동차그룹이 미래 먹거리로 낙점했던 수소차 개발 속도를 조정하고 나섰다. 수소전기트럭은 경쟁력과 성능이 검증된 만큼 보급에 드라이브를 거는 반면, 승용차 부분은 3세대 연료전지시스템 개발이 예상보다 지연되면서 신" property="og:description"/>
# <meta content="동아일보 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="동아일보" name="twitter:creator"/>
# <meta content="https://imgnews.pstatic.net/image/020/2023/01/10/0003473040_001_20230110150802674.jpg?type=w800" name="twitter:image"/>
# <meta content="현대자동차그룹이 미래 먹거리로 낙점했던 수소차 개발 속도를 조정하고 나섰다. 수소전기트럭은 경쟁력과 성능이 검증된 만큼 보급에 드라이브를 거는 반면, 승용차 부분은 3세대 연료전지시스템 개발이 예상보다 지연되면서 신" name="twitter:description"/>
# <meta content="gdid=880000A9_000000000000000003473040,service=news,collection=news,section=101" name="napp-site-analysis"/>
# <title>현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해</title>
# <link href="https://static-nnews.pstatic.net/css/min/20221229a/news.css" rel="stylesheet"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20230105-230105-151027-f7755848f-4g8gm";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "020",
# 				articleId: "0003473040",
# 				sectionId : "101",
# 				gdid: "880000A9_000000000000000003473040",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "101",
# 					secondSection: "263",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "동아일보",
# 				category : "종합지"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setAdDeduplication("article_body_dedup");
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newsend",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: "empty",
# 					unitId: "m_test",
# 					sync: false,
# 					mobileOnly: true,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20221229/common.min.js"></script>
# </head>
# <body class="n_news_mnews fs2 as_mp_layout">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP" style="position: relative;">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="tab">
# <a class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20230110151035.230";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_scroll_wrapper">
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT"><div class="newsct" id="ct" role="main">
# <div class="media_end_head go_trans">
# <div class="media_end_head_top">
# <a class="media_end_head_top_logo" href="http://www.donga.com/">
# <img alt="동아일보" class="media_end_head_top_logo_img light_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2019/01/22/logo_020_6_20190122142722.png" title="동아일보" width=""/>
# <img alt="동아일보" class="media_end_head_top_logo_img dark_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/07/23/dark_logo_020_6_20200723180516.png" title="동아일보" width=""/>
# </a>
# <div class="media_end_head_top_channel _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="media_end_head_top_channel_add _CHANNEL_BUTTON" data-clk-add="chmain020" data-clk-remove="chdelete020" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독">구독</button>
# <a class="media_end_head_top_channel_layer _LINK" data-clk="chlook" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_020_0003473040" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>동아일보</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서  주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_end_head_top_channel_layer_link">보러가기</span>
# </a>
# <p class="media_end_head_top_channel_layer" id="_CHANNEL_REMOVE_LAYER_020_0003473040" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>동아일보</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# </div>
# <div class="media_end_head_title">
# <h2 class="media_end_head_headline" id="title_area"><span>현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해</span></h2>
# </div>
# <div class="media_end_head_info nv_notrans">
# <div class="media_end_head_info_datestamp">
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2023-01-10 15:08:02">2023.01.10. 오후 3:08</span>
# </div>
# <a class="media_end_head_origin_link" data-clk="are.ori" data-extra='{"lk":{"oid":"020","aid":"0a421ce7b58ebab9"}}' data-gdid="020" href="https://www.donga.com/news/article/all/20230110/117372529/1" target="_blank">기사원문</a>
# </div> <div class="media_end_head_info_variety">
# <div class="media_end_head_info_variety_left" id="commentFontGroup">
# <div class="media_end_head_info_variety_likeit _LIKE_HIDE as_likeit_improve">
# <!-- 좋아요 -->
# <div class="_reactionModule u_likeit nv_notrans" data-cid="ne_020_0003473040" data-sid="NEWS">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face _LIKE_BUTTON" data-clk="RTL.face" data-label="recommend">
# <span class="u_likeit_icons _icons">
# <span class="u_likeit_icon __reaction__zeroface"></span>
# </span>
# <span class="u_likeit_text _count">추천</span>
# </a>
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.wow|RTL.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.touched|RTL.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.analytical|RTL.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.recommend|RTL.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <!-- 좋아요 -->
# </div>
# <div class="media_end_head_info_variety_cmtcount _COMMENT_HIDE">
# <a class="media_end_head_cmtcount_button _COMMENT_COUNT_VIEW" data-clk="rplt" data-max-limit="true" data-zero-allow="false" href="/mnews/article/comment/020/0003473040" id="comment_count">댓글</a>
# </div>
# </div>
# <div class="media_end_head_info_variety_right">
# <!-- 요약봇 -->
# <div class="media_end_head_autosummary _auto_summary_wrapper _SUMMARY _LIKE_HIDE" data-articleid="0003473040" data-officeid="020" id="_SUMMARY_BUTTON">
# <a class="media_end_head_autosummary_button _toggle_btn _SUMMARY_BTN" data-clk="sum" href="javascript:;"><span class="blind">본문 요약봇</span></a>
# <div class="media_end_head_autosummary_layer_dimmed _SUMMARY_DIMMED" style="display: none;"></div>
# <div class="media_end_head_autosummary_layer _auto_summary_contents _SUMMARY_LAYER" style="display: none;">
# <div class="media_end_head_autosummary_layer_head">
# <strong class="media_end_head_autosummary_layer_head_tit">본문 요약봇<a class="media_end_head_autosummary_help" data-clk="help" href="https://help.naver.com/alias/news/news_022.naver">도움말</a></strong>
# <span class="media_end_head_autosummary_layer_head_txt">자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.</span>
# <a class="media_end_head_autosummary_layer_close _close_button _SUMMARY_CLOSE_BTN" data-clk="close" href="javascript:;"><span class="blind">닫기</span></a>
# </div>
# <div class="media_end_head_autosummary_layer_body">
# <div class="_contents_body _SUMMARY_CONTENT_BODY"></div>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="media_end_head_tts nv_notrans" id="tts_player_div_wrap">
# <button class="media_end_head_tts_run _TTS_SETTING_BTN" data-clk="wtts" title="텍스트 음성 변환 서비스" type="button"><span class="blind">텍스트 음성 변환 서비스 사용하기</span></button>
# <div class="media_end_head_tts_setlayer nv_notrans _TTS_SETTING_LAYER">
# <div class="media_end_head_tts_setlayer_select">
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectGender">
# <em class="media_end_head_tts_option_tit">성별</em>
# <button class="media_end_head_tts_option" data-clk="ttsma" type="button" value="m">남성</button>
# <button class="media_end_head_tts_option" data-clk="ttsfe" type="button" value="f">여성</button>
# </div>
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectSpeed">
# <em class="media_end_head_tts_option_tit">말하기 속도</em>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="3">느림</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="2">보통</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="0">빠름</button>
# </div>
# <p class="media_end_head_tts_desc">이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.</p>
# <button class="media_end_head_tts_apply _TTS_LISTEN_BTN" data-clk="ttsstart" type="button">본문듣기 시작</button>
# </div>
# <button class="media_end_head_tts_setlayer_close _TTS_SETTING_LAYER_CLOSE_BTN" data-clk="ttsclose" type="button"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div id="tts_player_div"></div> <!-- 폰트 사이즈 -->
# <div class="media_end_head_fontsize _font_size_config_wrapper _FONT_WRAP">
# <a class="media_end_head_fontsize_set _font_size_config_toggle_btn _FONT_BUTTON" data-clk="fsz" href="#"><span class="blind">글자 크기 변경하기</span></a>
# <div class="media_end_head_fontsize_setlayer _FONT_LAYER">
# <ul class="media_end_head_fontsize_setlayer_select">
# <li class="media_end_head_fontsize_option1 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">가<em class="blind">1단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">작게</a>
# </li>
# <li class="media_end_head_fontsize_option2 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">가<em class="blind">2단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">보통</a>
# </li>
# <li class="media_end_head_fontsize_option3 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">가<em class="blind">3단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">크게</a>
# </li>
# <li class="media_end_head_fontsize_option4 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">가<em class="blind">4단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">아주크게</a>
# </li>
# <li class="media_end_head_fontsize_option5 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">가<em class="blind">5단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">최대크게</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_share nv_notrans">
# <a class="u_btn_sns_share naver-splugin spi_sns_share nv_notrans _SHARE_BUTTON" data-band-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=blog" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=calendar" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;oid=020&amp;aid=0003473040&amp;sid1=001" data-clk="ushr" data-facebook-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/020/2023/01/10/0003473040_001_20230110150802674.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=kakao" data-likecontentsid="ne_020_0003473040" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=mypeople" data-style="type_a" data-title="현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해" data-twitter-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/020/0003473040" href="#" id="spiButton" onclick="return false">
# <span class="naver-splugin-c send_caption"><span class="u_hc">SNS 보내기</span></span>
# </a>
# </div>
# <div class="media_end_head_print">
# <a class="media_end_print_link _PRINT_BUTTON" data-clk="print" data-print-url="/mnews/article/print/020/0003473040" href="#"><span class="blind">인쇄하기</span></a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="newsct_body" id="contents">
# <div class="newsct_article _article_body" id="newsct_article">
# <div class="go_trans _article_content" id="dic_area">
# 			현대자동차그룹이 미래 먹거리로 낙점했던 수소차 개발 속도를 조정하고 나섰다. 수소전기트럭은 경쟁력과 성능이 검증된 만큼 보급에 드라이브를 거는 반면, 승용차 부분은 3세대 연료전지시스템 개발이 예상보다 지연되면서 신차 개발 계획도 연기하고 있다.<br/><br/> 정의선 현대차그룹 회장은 3일 공개한 2023년 새해 메시지에서 수소를 언급하지 않고 넘어갔다. 정 회장은 1년 전에는 수소 사업에 대해 “다양한 모빌리티와 산업분야의 동력원으로 활용될 수 있도록 하겠다”며 관련 전략 확보를 주문한 것과 대비된다. 그나마 장재훈 현대차 사장이 내년 사업 계획을 소개하며 “중장기적으로 수소 생태계에 대한 이니셔티브(주도권)를 확보하고, 수소 생산과 유통 등 밸류 체인(공급망) 전반을 구축하겠다”고 언급한 정도다.<br/><br/> 현대차그룹은 세계 완성차 업체 중 수소차에 대해서는 세계 선두권으로 꼽힌다. 10일 시장조사기관 SNE리서치에 따르면 지난해 1~11월 수소차 판매 대수는 1만8457대이며, 이 중 현대차 넥쏘의 비중이 1만700대로 58.0%를 차지했다. 2위인 일본 도요타의 미라이가 3238대(17.5%)에 그쳤으며, 나머지 브랜드 차들의 판매량은 1000대에 미치지 못했다. <br/><br/><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/020/2023/01/10/0003473040_001_20230110150802674.jpg?type=w647" id="img1"/>
# </div>
# </div><em class="img_desc">지난해 8월 경기 고양시 킨텍스에서 열린 수소 산업 전시회 H2 MEET 2022’에서 공개된 수소전기트럭 청소차. 현대자동차 제공.</em></span> 특히 상용차 분야에서는 세계 최초의 상용 수소전기트럭 ‘엑시언트’를 앞세워 사실상 시장을 창출하고 있다는 평가다. 현대차그룹은 지난해 12월 수소전기트럭 엑시언트를 국내에 공식 판매하기 시작했다. 또한 지난해 12월 수소사업 브랜드 에이치투(HTWO)를 통해 독일 파운그룹 자회사 엔지니어스에 상용차 양산을 위한 수소연료전지 공급 계약을 맺었고, 비슷한 시기 이스라엘 시장 진출을 발표하기도 했다. 자동차업계 관계자는 “현대차그룹은 기술력, 양산 능력, 성능 검증 등을 모두 끝마친 유일한 완성차 업체”라며 “비슷한 사업을 추진하는 다른 회사들의 견제가 있지만 단기간 내 뒤집기 어려운 수준의 격차가 있다”고 분석했다. 여기에 유럽연합(EU)이 2027년까지 수소 충전소 의무 설치 간격을 150㎞에서 100㎞로 강화한 점, 미국의 정부의 95억 달러 규모 수소허브 건설 계획 등 정책 환경도 현대차에 유리한 상황이다.<br/><br/> 하지만 현대차그룹은 수소차 관련 사업 계획을 전면 재편하며 분위기 전환에 나선 상황이다. 현대차그룹은 지난해 말 임원 인사를 통해 그동안 수소 사업을 담당해온 부사장급 수소연료전지개발센터장과 수소연료전지사업부장을 모두 교체했다. 현대차 안팎에서는 3세대 수소연료전지 시스템 개발 지연에 대한 책임을 물었다는 분석이 나온다.<br/><br/><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a2">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/020/2023/01/10/0003473040_002_20230110150802711.jpg?type=w647" id="img2"/>
# </div>
# </div><em class="img_desc">현대 수소연료전지 승용차 넥쏘. 현대자동차 제공.</em></span> 현대차그룹은 애초 2021년 수소 사회 미래상을 제시한 ‘하이드로젠 웨이브’ 행사에서 가격은 절반 수준으로 낮추고 내구성과 출력을 강화한 수소연료전지 시스템을 2023년까지 내놓겠다는 계획을 밝혔다. 하지만 개발이 더디게 진행되면서 수소 관련 로드맵이 3~4년 정도 늦춰졌고, 넥쏘 후속 모델 출시도 지연되는 상황이다. 이에 대해 장재훈 사장은 지난해 8월 “장기적으로 수소 관련 제품의 경쟁력을 높이기 위해 개발 목표를 더 높였다”고 설명하기도 했다.<br/><br/> 자동차업계에서는 현대차 업계가 수소 사업과 관련해 선택과 집중에 나선 것으로 보고 있다. 수소전기트럭은 사업성이 높고 정책 수혜가 기대되는 만큼 양산과 보급에 집중하되, 승용차는 상품성 확보를 위한 연구개발(R&amp;D)에 집중한다는 것이다. 자동차업계 관계자는 “현대차그룹이 전기차에서 성과를 내면서 수소 승용차 개발에는 상대적으로 여유가 생긴 것도 사실”이라고 전했다.<br/><br/>
# </div>
# </div>
# <div class="byline">
# <p class="byline_p">
# <span class="byline_s">이건혁 기자 gun@donga.com</span>
# </p>
# </div>
# <div class="copyright">
# <div class="c_inner">
# <p class="c_text">Copyright ⓒ 동아일보. All rights reserved. 무단 전재 및 재배포 금지.</p>
# </div>
# </div> <div class="media_end_categorize">
# <a class="media_end_categorize_link _categorize_title _TOGGLE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">이 기사는 언론사에서 <em class="media_end_categorize_item">경제</em>, <em class="media_end_categorize_item">생활</em> 섹션으로 분류했습니다.</a>
# <div class="media_end_categorize_ct" id="_ARTICLE_SECTION_GUIDE_LAYER">
# <em class="media_end_categorize_ct_title">기사 섹션 분류 안내</em>
# <p class="media_end_categorize_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>
# <a class="media_end_categorize_ct_close _CLOSE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">닫기</a>
# </div>
# </div>
# <div id="channelBanner" style="display:none;">
# <div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# <a class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chbanner020" data-clk-remove="chsee020" data-notification="true" data-notification-clk="notbb" href="#">
# <div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# <div class="media_end_channel_banner_img">
# <img alt="동아일보" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_57_20200917112528.jpg" height="40" style="display:none;" width="40"/>
# </div>
# </div>
# <div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# <p class="media_end_channel_banner_add">구독</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# </div>
# <div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# <p class="media_end_channel_banner_add is_disabled">구독중</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span> <em>보러가기</em></p>
# </div>
# </a>
# </div>
# </div>
# <div id="channelBannerRecommendList"></div>
# <script class="_CHANNEL_BANNER_RECOMMEND_LIST" type="x-tmpl-mustache">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">추가 구독해보세요</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt=""></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# <div class="promotion">
# <ul class="p_list">
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://www.donga.com/news/Newsletter">동아일보 [뉴스레터] 구독하기</a>
# </li>
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://media.naver.com/channel/promotion.nhn?oid=020">네이버에서 [동아일보] 채널 구독하기</a>
# </li>
# </ul>
# </div> <div class="media_end_linked">
# <h3 class="media_end_linked_title">
# <a class="media_end_linked_title_inner" href="http://www.donga.com/">
# <img alt="동아일보" class="media_end_linked_title_img light_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2019/01/22/logo_020_6_20190122142722.png" title="동아일보" width=""/>
# <img alt="동아일보" class="media_end_linked_title_img dark_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/07/23/dark_logo_020_6_20200723180516.png" title="동아일보" width=""/>
# </a>
# 			주요뉴스<span class="media_end_linked_title_desc">해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span>
# </h3>
# <ul class="media_end_linked_list">
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"020","aid":"bb8f97887bdcec48"}}' data-gdid="020" href="https://www.donga.com/news/Politics/article/all/20230109/117353207/1?gid=117372529&amp;srev=1&amp;regdate=20230110" target="_blank">1년 뒤에 또 펼쳐질 '번갯불에 콩 볶는 쇼'</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"020","aid":"9ba95269ed665bf7"}}' data-gdid="020" href="https://www.donga.com/news/Society/article/all/20230110/117371049/1?gid=117372529&amp;srev=1&amp;regdate=20230110" target="_blank">이재명 檢출석에 1100여명 찬반 집회"李 지키자" "구속하라"</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"020","aid":"2e81f8656f482ca5"}}' data-gdid="020" href="https://www.donga.com/news/Politics/article/all/20230110/117370759/1?gid=117372529&amp;srev=1&amp;regdate=20230110" target="_blank">나경원, 尹에 저출산委 부위원장직 사의 표명</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"020","aid":"42b7c25086966b30"}}' data-gdid="020" href="https://www.donga.com/news/Society/article/all/20230110/117370329/2?gid=117372529&amp;srev=1&amp;regdate=20230110" target="_blank">"김만배, 권순일에 '언론사 회장직' 제안"</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"020","aid":"cecc2bdf313eb181"}}' data-gdid="020" href="https://www.donga.com/news/Inter/article/all/20230110/117370849/2?gid=117372529&amp;srev=1&amp;regdate=20230110" target="_blank">中, 한국인 단기비자 발급 전격중단…입국규제 보복</a></li>
# </ul>
# </div>
# <div class="r_group_comp ad_box _da_banner is_border_none">
# <div class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-article="false" data-mobileonly="false" data-persist="1_ad" data-sync="false" data-unitid="p_news_newsend" id="nmap_c_020_0003473040_101_1"></div>
# </div>
# <script>
# 	window.__htExternalUrl = window.__htExternalUrl || {};
# 	window.__htExternalUrl["like"] = "https://news.like.naver.com/js/reaction/dist/reaction.min.js";
# 	window.__htLikeOption = {
# 		type: "multi",
# 		cssId: "news",
# 		domain: "https://news.like.naver.com",
# 		isMobile: true,
# 		isHiddenLabel: false,
# 		isHiddenCount: false,
# 		isHiddenZeroCount: false,
# 		isUsedLabelAsZeroCount: false,
# 		isDebugMode: false,
# 		isDuplication: false,
# 		isHiddenLayerAfterSelection: true,
# 		clicklog: function(el, name) {
# 			nclkWrap.send({
# 				$this: $(el),
# 				sArea: name
# 			});
# 		}
# 	};
# 	window.__htLikeOption["isZeroFace"] = true;
# 	</script>
# <div class="ends_btn _PERSIST_HEIGHT _LIKE_HIDE as_likeit_improve" data-persist="0_faceLike">
# <div class="ends_btn_head">
# <strong class="ends_head_title">이 기사를 추천합니다</strong>
# <button class="ends_help_btn _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.info" data-target="_LIKE_INFO_LAYER" type="button"></button>
# <div class="ends_help_layer is_hidden" id="_LIKE_INFO_LAYER">
# <p class="ends_help_desc">기사 추천은 24시간 내 50회까지 참여할 수 있습니다.</p>
# <button class="ends_help_close _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.infoclose" data-target="_LIKE_INFO_LAYER"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div class="_reactionModule u_likeit" data-cid="ne_020_0003473040" data-sid="NEWS" id="likeItCountViewDiv" style="visibility: visible;">
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.useful|RTC.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.wow|RTC.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.touched|RTC.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.analytical|RTC.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.recommend|RTC.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <div class="u_likeit_module u_btn_likeit_on" id="likeItSTimeLineShareDiv" style="display:none"></div>
# <div class="u_likeit_module" id="likeItScrollDiv" style="display:none">
# <div class="u_likeit_friends" id="likeItFriendListDiv"></div>
# </div>
# </div> <div class="ends_addition" id="endAdditionContainer">
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["share"] = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js";
# 			window.__htShareOption = {
# 				"scriptUrl": window.__htExternalUrl["share"],
# 				"evKey": "news",
# 				"dimmed": "fixed",
# 				"serviceName": "뉴스",
# 				"sourceName": "동아일보"
# 			};
# 			if (isAvailableDarkMode) {
# 				window.__htShareOption["darkMode"] = true;
# 			}
# 		</script>
# <div id="spiLayer" style="display:none;">
# <div class="spi_wrap layer_share_on">
# <div class="spi">
# <div class="spug">
# <a class="naver-splugin _spi_release spi_ico _btn_postbtn sns_share" data-band-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=blog" data-button="postbtn" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=calendar" data-clk="dshr" data-facebook-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/020/2023/01/10/0003473040_001_20230110150802674.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=kakao" data-likecontentsid="ne_020_0003473040" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=mypeople" data-style="type_a" data-title="현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해" data-twitter-url="https://n.news.naver.com/mnews/article/020/0003473040?lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/020/0003473040" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="tomain_info _LIKE_HIDE" id="_TOMAIN_INFO" style="display: none;">
# <p class="tomain_info_layer">
# <strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# <span class="tomain_info_body">
# <strong class="tomain_info_point">이 기사를 추천합니다 </strong><span class="tomain_info_text">버튼을 눌러주세요. <br/> 집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.</span>
# </span>
# <a class="tomain_info_close _CLOSE" data-target="_TOMAIN_INFO" href="#">레이어 닫기</a>
# </p>
# </div>
# </div> <div class="_VALID_SERIES" data-component-id=""></div>
# <div class="media_end_linked_more">
# <div class="media_end_linked_more_inner">
# <a class="media_end_linked_more_link" data-clk="phome" data-gdid="020" href="https://media.naver.com/press/020"><em class="media_end_linked_more_point">동아일보</em> 언론사홈 바로가기</a>
# </div>
# </div>
# <script>
# 		window.__htExternalUrl = window.__htExternalUrl || {};
# 		window.__htExternalUrl["tip"] = "https://ssl.pstatic.net/dicimg/tip/tip_m.js";
# 		window.__htExternalUrl["pcTip"] = "https://ssl.pstatic.net/dicimg/tip/tip_pc.js";
#
# 		window.__htExternalUrl["handOff"] = {
# 			"category": "news_article",
# 			"apiDomain": "https://sidekick.fever.naver.com"
# 		};
# 	</script> <div class="subscribe_cta_layer" id="_MODAL_LAYER_FOR_UNSUBSCRIBER_PROMOTION">
# <button class="cta_btn as_subscribe _CHANNEL_ADD" data-clk-add="mediaflw" data-delay="1000" data-notification="true" type="button">
# <span class="cta_text"><em class="cta_text_em">언론사 구독 후</em> 기사보기</span>
# <i class="cta_arrow"></i>
# </button>
# <button class="cta_btn _UNSUBSCRIBER_PROMOTION_CLOSE" data-clk="medianoflw" type="button">
# <span class="cta_text"><em class="cta_text_em">구독 없이</em> 계속 보기</span>
# <i class="cta_arrow"></i>
# </button>
# </div>
# </div>
# </div>
# <div class="box1 more_news2">
# <h4>
# 더 많은 콘텐츠를 만나는 방법
# </h4>
# <div class="type2">
# <a class="thumb" href="https://blog.naver.com/premiumcontents/222970178606" onclick="nclk(event,'wit.img','','1');"><img alt="섬네일 이미지" height="80" onerror="javascript:this.src='https://imgnews.pstatic.net/image/news/2009/noimage_120x90.gif';this.style.width=115;this.style.height=80;" src="https://scs-phinf.pstatic.net/MjAyMzAxMDJfMjg3/MDAxNjcyNjQ0NDAzOTU3.tNhHCTc5r3QjdGdc8Qdvmsn-UiYlrTWe7AIMwM-3ZMAg.TjyNqRKxNzV-lZzVH9S4TpT-bSdyiGRvqMQvqqa2Pocg.JPEG/image%7Cpremium%7Ctest%7Cbanner%7C2023%7C01%7C02%7C%EB%AA%A8%EB%B0%94%EC%9D%BC_%EA%B8%B0%EC%82%AC_%EB%B3%B8%EB%AC%B8_460X320.jpg" width="115"/><span class="frame"></span></a>
# <a href="https://blog.naver.com/premiumcontents/222970178606" onclick="nclk(event,'wit.tit','','1');">
# <strong>이번에도 작심삼일? NO! 새해에는 '갓생 살자!'</strong>
# <p>우리의 결심을 도와줄 프리미엄콘텐츠, 첫 달 무료로 구독하세요. </p>
# </a>
# </div>
# </div>
# <div class="check_visible" id="frontDetect"></div>
# <div class="office_headline more_news optional_hidden pc_hidden _FLICKING_WRAP _OFFICE_HEADLINE _PERSIST_HEIGHT _PERSIST_META" data-count="3" data-flicking-nclk="false" data-grid-template-column-aside="" data-nclk-prefix="art" data-persist="3_officeHeadline">
# <div class="ofhe_head">
# <div class="ofhe_head_inner">
# <h2 class="ofhe_head_title">
# <a class="ofhe_head_title_link" data-clk="art.pheadhome" href="https://media.naver.com/press/020">
# <em>동아일보</em> 헤드라인
# 					</a>
# </h2>
# </div>
# </div>
# <div class="ofhe_body flick">
# <div class="flick-container _FLICKING" style="height: 161px; opacity:0;">
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/020/0003473027">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/10/3473027.jpg?type=nf336_206&amp;ut=20230110142401"/>
# </div>
# </div>
# <div class="ofhe_headline">中, 한국인 단기비자 발급 전격중단…입국규제 보복</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">중국이 10일 한국 입국자에 대한 단기비자를 중단했다. 우리 정부가 단기 비자 발급 제한과 항공편 증편 중단 등 중국 단순 관광객의 입국을 사실상 차단하자 보복 조치에 나선 것으로 보인다. 주한중국대사관은 이날 ‘한</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/020/0003473025">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/10/3473025.jpg?type=nf336_206&amp;ut=20230110150601"/>
# </div>
# </div>
# <div class="ofhe_headline">나경원, 尹에 저출산委 부위원장직 사의 표명</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">국민의힘 당권주자로 거론되는 나경원 전 의원이 10일 윤석열 대통령에게 저출산고령사회위원회 부위원장직 사의를 표명했다. 정치권에 따르면 나 전 의원은 이날 오후 대통령실 김대기 비서실장을 통해 사의를 전하고 “대통령</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/020/0003473015">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/10/3473015.jpg?type=nf336_206&amp;ut=20230110120101"/>
# </div>
# </div>
# <div class="ofhe_headline">이재명은 ‘안방여포’ 운운할 자격이 있나[김지현의 정치언락]</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">의뭉스러운 섬 여의도에선 오늘도 진심을 숨긴 속내, 사실에 가까운 거짓말들이 쏟아집니다. 정치인들의 능글맞은 말과 미묘한 글 뒤에 숨겨진 진의, 그들이 공개적으로는 말하지 않는 진짜 뒷이야기, ‘언락’(Unlock)</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/020/0003473018">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/10/3473018.jpg?type=nf336_206&amp;ut=20230110133101"/>
# </div>
# </div>
# <div class="ofhe_headline">내 집 뒤의 공사판은 적신호![안영배의 웰빙풍수]</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">경기도 과천시 한 단독주택에서 전세살이를 하고 있는 이수영씨(58). 쾌적한 환경을 갖춘 데다가 명당 터라는 조언을 듣고서 이 집에서 산 지 올해로 4년째다. 이씨는 곧 전세 만료를 앞두고 매입할지 이사할지를 결정지</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/020/0003473019">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/10/3473019.jpg?type=nf336_206&amp;ut=20230110132401"/>
# </div>
# </div>
# <div class="ofhe_headline">골목길서 ‘빵’ 경적에 놀란 할머니, 크게 다쳤다…누구 잘못?</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">골목길을 걷던 할머니가 뒤에서 오던 차량의 경적 소리에 놀라 넘어졌다. 사고 후 할머니는 고관절 골절 수술을 받은 것으로 전해졌다. 운전자 측은 이에 억울함을 호소하며 직접적으로 부딪힌 사고가 아니더라도 과실이 있는</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link" data-clk="art.phead" href="/mnews/article/020/0003473001">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/10/3473001.jpg?type=nf336_206&amp;ut=20230110150701"/>
# </div>
# </div>
# <div class="ofhe_headline">서울의 명산이 수묵화로 피어나는 순간…도봉산에서 만난 상고대[전승훈의 아트로드]</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">겨울 산행에서 가장 진귀한 구경은 상고대다. 상고대를 구경하려면 강원도의 계방산, 태백산, 함백산, 제주 한라산처럼 서울에서 멀고 높은 산을 찾아야 한다는 생각이 든다. 그런데 지난 주말 도봉산 산행을 갔다가 정상부</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="ofhe_paginate pg">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" type="button"><span class="blind">이전 뉴스들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" type="button"><span class="blind">다음 뉴스들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 	{{#selected}}
# 		<div class="pg_num pg_num_cur">{{number}}</div>
# 	{{/selected}}
# 	</script>
# </div>
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["comment"] = "https://ssl.pstatic.net/static.cbox/js/cbox.core.js";
# ...
# </div>
# <div class="rl_author_name">연령제한</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzAxMDlfNjkg/MDAxNjczMjI3MDE0NTE2.Rc5eA6fYF3kbFcUzIbuxSPzMX830U8Bfhrq7KqynAqog.M1opfiLSf-K-9RwvS33b2OE58qbgvTisjGKFUlb5aEAg.JPEG/20230104180854_nvbkupqz.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ranking_list _FLICKING_CONTENT">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.9044851865209362" href="https://contents.premium.naver.com/tokenpost/tokenpostplus/contents/230102151244164pl?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										[THINKING] DAO와 웹3.0이 가져올 지식재산분쟁(1부)
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMTEyMjdfMjc1/MDAxNjQwNTgxOTA3MzMz.2qMWiHe3gAh2kjo0N2G6xDhSIG2uJncaRkhL9NufVtQg._sevhmRMs5P2HqhBvv5GvgcRS_DTeHEKoWhDGIY0Hksg.JPEG/image%7Cpremium%7Cchannel%7Ctokenpost%7C2021%7C12%7C27%7C1640581907301.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">토큰포스트 플러스</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzAxMDJfMjAg/MDAxNjcyNjM5Nzc4MDY0.Ty-c8T6f_IgC8pEXpHAq0LxlhBNxQACpBq07GlTbv5og.NsiyfMb5i6FdBi3SDKjgnAmX1WFg6VL4njzsCcrkz7og.JPEG/SE-6d3af296-9c48-45cc-82af-f890dfcc63ba.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8026414501869608" href="https://contents.premium.naver.com/u6123/u612345/contents/230102200444783vp?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										유튜브를 해야 하는 이유
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA5MTlfMTM4/MDAxNjYzNTk0ODQ4NTE5.W52HIooNZub9yyAMOUmE-ahw4qGhzHt57zx8AWgJ3uEg.KFnXOI477QtrJtbxddXjKyHiktftUhRkGw81JHWt2gcg.JPEG/image%7Cpremium%7Cchannel%7Cu6123%7C2022%7C09%7C19%7C1663594848508.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">책읽는책돌이</div>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8326824079904058" href="https://contents.premium.naver.com/upcle/upclenews/contents/230109214623537wu?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										공기는 왜 이 모양일까요?
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA2MjRfMjg1/MDAxNjU2MDY5NTAyODgy.ewlQbp6qG5j0S-kuZg7y-6thGrIT9XVXzaaAw_QG25gg.rcEQ_0B9vkTbVSvrRgNvw-ARPttP9-yemudZRfLWI0gg.PNG/image%7Cpremium%7Cchannel%7Cupcle%7C2022%7C06%7C24%7C1656069502851.png?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">업클</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzAxMDlfNTgg/MDAxNjczMjY4MDAyMzQy.5Cy81nvwrrFMHDIEocSlPc9XW3gjXcDPWGR37WdOo0gg.-3qousxdgOMoJRfsamk6je9fAVQZyn0tPseSNEhuaBQg.JPEG/%EB%AF%B8%EC%84%B8%EB%A8%BC%EC%A7%80.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="1.0137155819847905" href="https://contents.premium.naver.com/backbriefing/news/contents/230110140706033xd?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										[저출산시리즈②]나경원이 말한 '헝가리 해법', 사실은 이렇다
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMTEyMjdfMTg4/MDAxNjQwNTkxMDEzOTQ4.wyQt-abxlprzGf0nL8twIlZxeUX6VFjY6KCwPrD9YrEg.wY0ichWQ3CXXLEhPo7HCB_mFo6OPDm7NRiHgZ-3wQFkg.PNG/image%7Cpremium%7Cchannel%7Cbackbriefing%7C2021%7C12%7C27%7C1640591013869.png?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">삼프로TV 하이라이트</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzAxMTBfNjgg/MDAxNjczMzE3NDk5OTQ5.Ajs0ZK9M9P8DFrVRs2iVe63aw-ibs0Cac62ucERcfHQg.8ZsefYtVaf09N2waZLLucRoDtbDWTsPIafQork5G9dwg.JPEG/%EC%A0%80%EC%B6%9C%EC%82%B0-1.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="pg ra_paginate">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" data-clk="arp.bprv" type="button"><span class="blind">이전 콘텐츠들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" data-clk="arp.bnxt" type="button"><span class="blind">다음 콘텐츠들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 			{{#selected}}
# 			<div class="pg_num pg_num_cur">{{number}}</div>
# 			{{/selected}}
# 		</script>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside?oid=020" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw" id="u_ftlkw">
# <a class="u_ftlk _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# <a class="u_ftlk _LINK" data-clk="fot.sitemap" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">뉴스도움말</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a></span>
# </span>
# <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단<br/>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER Corp.</a></span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1">동아일보</a></span>
# </p>
# </footer>
# </div>
# </div><div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 기사는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20221229/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20221229/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {"id":"101","name":"경제"};
# 		var redirectSection = {"id":"101","name":"경제"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "http://news.naver.com/main/read.nhn?oid=020&aid=0003473040";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("unload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var fnOnUnload = window.onunload;
# 				window.onunload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
#
# 	if (typeof BMR !== "undefined") {
# 		BMR.run("https://sp.naver.com/sp");
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do_gdid("880000A9_000000000000000003473040");
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": (/\/article\/comment\//.test(location.href) == true) ? "댓글" : "본문",
# 					},
# 					"extraInfo": {
# 						"articleId": article.articleId,
# 						"sectionId": article.sectionId,
# 						"officeId": article.officeId,
# 						"articleType": article.type
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data,
# 						contentBodyEl: document.querySelector("._article_content"),
# 						contentBodyVideoWrapperSelector: "._VIDEO_AREA"
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %% [markdown]
# ### 한 페이지 모든 기사

# %%
titles = []
urls = []
for url_and_title in urls_and_titles :
    if len(url_and_title) == 1:
        title = url_and_title.text.strip()
        url = url_and_title.get("href").strip()
        titles.append(title)
        urls.append(url)
    else :
        continue

titles
# titles = [url_and_title.text.strip() for url_and_title in urls_and_titles]
# titles
# Out:
# ['현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해',
#  '아웃백 품은 bhc그룹, ‘매출 1조’ 클럽 입성… “2030년 3조 원 목표”',
#  '지구에 희소식…“오존층 점점 회복…2040년이면 1980년대 수준으로”',
#  '기아, ‘경차 모닝’ 할부 부담 완화… 한국은행 기준금리 적용',
#  '檢출석 이재명, “쫄았냐”는 시민에 ‘쉿’…날 선 신경전',
#  '서울 초6·중3 ‘기초학력 보장 채움학기’ 운영…학습부진 해소',
#  '불륜설 휘말린 UN 최정원 “말도 안 돼…가족도 알고 지낸 동생”',
#  '대법, ‘스토킹 살인’ 김병찬 징역 40년 확정',
#  '청년 고용 한파…고용보험 가입자수 넉달째 감소',
#  'SKT, 오픈랜 가상화 기지국 국내 첫 상용망 실증',
#  '31년 만에 30대 신부가 더 많아졌다…20대 신부 수 추월',
#  '현대차, 계묘년 맞이 ‘MobED와 B.B.래빗의 신비로운 여행’ 전시',
#  '이재명 檢출석…“李 지키자” “구속하라” 1100여명 찬반 집회',
#  '中, 한국인 단기비자 발급 전격중단…입국규제 보복',
#  '손흥민의 동료였던 개러스 베일 은퇴…베일 “내 인생 최고의 순간이었다”',
#  '나경원, 尹에 저출산委 부위원장직 사의 표명',
#  '운동에 식단 더한다… 현대그린푸드, 커브스코리아와 업무협약',
#  '“김만배, 권순일에 ‘언론사 회장직’ 제안”',
#  '“가스배관 타고 망봐주고” 교도소 동기끼리 빈집 털다 붙잡혀',
#  "넥슨의 2023년 첫 신작 '나이트 워커' 어떤 게임일까?"]

# %%
urls
# urls = [url_and_title.get("href").strip() for url_and_title in urls_and_titles ]
# urls
# Out:
# ['https://n.news.naver.com/mnews/article/020/0003473040',
#  'https://n.news.naver.com/mnews/article/020/0003473039',
#  'https://n.news.naver.com/mnews/article/020/0003473038',
#  'https://n.news.naver.com/mnews/article/020/0003473037',
#  'https://n.news.naver.com/mnews/article/020/0003473036',
#  'https://n.news.naver.com/mnews/article/020/0003473035',
#  'https://n.news.naver.com/mnews/article/020/0003473034',
#  'https://n.news.naver.com/mnews/article/020/0003473033',
#  'https://n.news.naver.com/mnews/article/020/0003473032',
#  'https://n.news.naver.com/mnews/article/020/0003473031',
#  'https://n.news.naver.com/mnews/article/020/0003473030',
#  'https://n.news.naver.com/mnews/article/020/0003473029',
#  'https://n.news.naver.com/mnews/article/020/0003473028',
#  'https://n.news.naver.com/mnews/article/020/0003473027',
#  'https://n.news.naver.com/mnews/article/020/0003473026',
#  'https://n.news.naver.com/mnews/article/020/0003473025',
#  'https://n.news.naver.com/mnews/article/020/0003473024',
#  'https://n.news.naver.com/mnews/article/020/0003473023',
#  'https://n.news.naver.com/mnews/article/020/0003473022',
#  'https://n.news.naver.com/mnews/article/020/0003473021']

# %%
contents = []
for url in tqdm(urls) :
    respone = requests.get(url, 
        headers={
            'User-Agent': 'Mozilla 5.0'
        }
    )
    bs = BeautifulSoup(respone.text,"lxml")
    if bs.select('#dic_area'):
        content = bs.select("#dic_area")[0].text.strip()

    if bs.select('#contents'):
        content = bs.select('#contents')[0].text.strip()

    if bs.select('.content'):
        content =  bs.select('.content')[0].text.strip()
    
    contents.append(content)
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.10it/s]

# %%
def bs_from_url(url) :
    respone = requests.get(url, 
        headers={
            'User-Agent': 'Mozilla 5.0'
        }
    )
    bs = BeautifulSoup(respone.text,"lxml")
    return bs

# %%
# contents = [bs_from_url(url).select("#dic_area")[0].text.strip() for url in urls]

# %%
pd.DataFrame({
    'date' : '20221206',
    'press_name' : '동아일보',
    'title': titles,
    'content' : contents,
    'content_link' : urls
})
# Out:
#         date press_name                                         title  \
# 0   20221206       동아일보           현대차, 수소차 개발 속도 조절…점유율 세계 1위에도 안심 못해
# 1   20221206       동아일보  아웃백 품은 bhc그룹, ‘매출 1조’ 클럽 입성… “2030년 3조 원 목표”
# 2   20221206       동아일보       지구에 희소식…“오존층 점점 회복…2040년이면 1980년대 수준으로”
# 3   20221206       동아일보            기아, ‘경차 모닝’ 할부 부담 완화… 한국은행 기준금리 적용
# 4   20221206       동아일보               檢출석 이재명, “쫄았냐”는 시민에 ‘쉿’…날 선 신경전
# 5   20221206       동아일보            서울 초6·중3 ‘기초학력 보장 채움학기’ 운영…학습부진 해소
# 6   20221206       동아일보          불륜설 휘말린 UN 최정원 “말도 안 돼…가족도 알고 지낸 동생”
# 7   20221206       동아일보                    대법, ‘스토킹 살인’ 김병찬 징역 40년 확정
# 8   20221206       동아일보                     청년 고용 한파…고용보험 가입자수 넉달째 감소
# 9   20221206       동아일보                  SKT, 오픈랜 가상화 기지국 국내 첫 상용망 실증
# 10  20221206       동아일보             31년 만에 30대 신부가 더 많아졌다…20대 신부 수 추월
# 11  20221206       동아일보       현대차, 계묘년 맞이 ‘MobED와 B.B.래빗의 신비로운 여행’ 전시
# 12  20221206       동아일보           이재명 檢출석…“李 지키자” “구속하라” 1100여명 찬반 집회
# 13  20221206       동아일보                   中, 한국인 단기비자 발급 전격중단…입국규제 보복
# 14  20221206       동아일보       손흥민의 동료였던 개러스 베일 은퇴…베일 “내 인생 최고의 순간이었다”
# 15  20221206       동아일보                      나경원, 尹에 저출산委 부위원장직 사의 표명
# 16  20221206       동아일보              운동에 식단 더한다… 현대그린푸드, 커브스코리아와 업무협약
# 17  20221206       동아일보                      “김만배, 권순일에 ‘언론사 회장직’ 제안”
# 18  20221206       동아일보             “가스배관 타고 망봐주고” 교도소 동기끼리 빈집 털다 붙잡혀
# 19  20221206       동아일보              넥슨의 2023년 첫 신작 '나이트 워커' 어떤 게임일까?
#
#                                               content  \
# 0   현대자동차그룹이 미래 먹거리로 낙점했던 수소차 개발 속도를 조정하고 나섰다. 수소전...
# 1   종합외식기업 bhc그룹이 매출 1조 원 클럽에 이름을 올렸다.bhc그룹은 지난해 그...
# 2   사진출처=NASA파괴된 오존층이 극지방을 제외하고 전 세계적으로 2040년까지 완전...
# 3   경차 모닝 전용 할부 프로모션한국은행 기준금리 적용\n\n\n\n기아 모닝기아는 경...
# 4   이재명 더불어민주당 대표가 성남FC 후원금 의혹 관련 조사를 받기 위해 10일 오전...
# 5   조희연 서울시교육감이 10일 서울 종로구 서울시교육청에서 ‘기초학력 보장 강화 방안...
# 6   그룹 UN 출신 가수 겸 배우 최정원이 불륜설을 부인하며 법적 대응을 하겠다고 밝혔...
# 7   2021년 11월 29일 서울 남대문경찰서에서 호송차로 향하는 김병찬. 뉴스1자신의...
# 8   지난달 고용보험 가입자 가운데 29세 이하 청년 가입자가 전달 대비 3만 명 감소해...
# 9   SKT 연구원들이 트래픽 혼잡 상황에 활용하는 솔루션을 테스트 하는 모습. SK텔레...
# 10  통계 작성 이래 최초 남녀 평균 초혼 연령, 30년전보다 5~6세 높아져\n\n\n...
# 11  현대자동차가 2023년 ‘검은 토끼의 해’인 계묘년을 맞아 토끼 캐릭터로 유명한 일...
# 12  이재명 더불어민주당 대표가 성남FC 후원금 의혹 사건 관련 조사를 받기 위해 10일...
# 13  중국에서 온 단기체류 외국인의 코로나19 누적 양성률이 21.7%를 기록한 8일 인...
# 14  손흥민의 동료였던 개러스 베일 은퇴…베일 “내 인생 최고의 순간이었다”\n\n기사입...
# 15  대통령실 “전혀 들은 바 없어” 반박\n\n\n\n나경원 대통령 직속 저출산고령사회...
# 16  현대백화점그룹 계열 종합식품기업 현대그린푸드가 여성 전용 피트니스 회원들에게 건강관...
# 17  권순일 전 대법관. 동아일보DB대장동 개발사업 특혜 의혹의 핵심 인물인 김만배 씨가...
# 18  게티이미지뱅크교도소에서 함께 수감생활을 한 2명이 출소 후 같이 시골 빈집들을 털다...
# 19  넥슨의 2023년 첫 신작 ‘나이트 워커’가 지난 1월 5일 사전 등록에 돌입했다....
#
#                                          content_link
# 0   https://n.news.naver.com/mnews/article/020/000...
# 1   https://n.news.naver.com/mnews/article/020/000...
# 2   https://n.news.naver.com/mnews/article/020/000...
# 3   https://n.news.naver.com/mnews/article/020/000...
# 4   https://n.news.naver.com/mnews/article/020/000...
# 5   https://n.news.naver.com/mnews/article/020/000...
# 6   https://n.news.naver.com/mnews/article/020/000...
# 7   https://n.news.naver.com/mnews/article/020/000...
# 8   https://n.news.naver.com/mnews/article/020/000...
# 9   https://n.news.naver.com/mnews/article/020/000...
# 10  https://n.news.naver.com/mnews/article/020/000...
# 11  https://n.news.naver.com/mnews/article/020/000...
# 12  https://n.news.naver.com/mnews/article/020/000...
# 13  https://n.news.naver.com/mnews/article/020/000...
# 14  https://n.news.naver.com/mnews/article/020/000...
# 15  https://n.news.naver.com/mnews/article/020/000...
# 16  https://n.news.naver.com/mnews/article/020/000...
# 17  https://n.news.naver.com/mnews/article/020/000...
# 18  https://n.news.naver.com/mnews/article/020/000...
# 19  https://n.news.naver.com/mnews/article/020/000...

# %% [markdown]
# ### 특정 날짜 전체 기사

# %%
url = "https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=020&date=20221206&page=100"
bs = bs_from_url(url)
last_page_num = int(bs.select('div.paging > strong')[0].text.strip())
last_page_num
# Out:
# 13

# %%
def bs_from_url(url) :
    respone = requests.get(url, 
        headers={
            'User-Agent': 'Mozilla 5.0'
        }
    )
    bs = BeautifulSoup(respone.text,"lxml")
    return bs

def whole_url_title(urls_and_titles):
    titles = []
    urls = []
    for url_and_title in urls_and_titles :
        if len(url_and_title) == 1:
            title = url_and_title.text.strip()
            url = url_and_title.get("href").strip()
            titles.append(title)
            urls.append(url)
        else :
            continue
    return titles,urls

def get_contents_from_url(url):
    bs = bs_from_url(url)

    if bs.select('#contents'):
        return bs_from_url(url).select('#contents')[0].text.strip()

    if bs.select('.content'):
        return bs_from_url(url).select('.content')[0].text.strip()

# %%
donga = pd.DataFrame()

for date in tqdm(pd.date_range('20230109','20230110')):
    date = date.strftime("%Y%m%d")
    for i in range (1,last_page_num+1):
        url = f"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=020&date={date}&page={i}"
        bs = bs_from_url(url)
        urls_and_titles = bs.select(".list_body.newsflash_body > ul dt > a")
        titles, urls = whole_url_title(urls_and_titles)
        contents = [get_contents_from_url(url) for url in urls]
        
        temp = pd.DataFrame({
            'date' : date,
            'press_name' : '동아일보',
            'content' : contents,
            'title' : titles,
            'url' : urls 
        })
        donga = donga.append(temp)

donga
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
#  50%|█████     | 1/2 [01:30<01:30, 90.31s/it]C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# C:\Users\82102\AppData\Local\Temp\ipykernel_17424\1092817857.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   donga = donga.append(temp)
# 100%|██████████| 2/2 [02:59<00:00, 89.96s/it]
#         date press_name                                            content  \
# 0   20230109       동아일보  박진 외교부 장관. (외교부 제공)친강(秦剛·57) 중국 신임 외교부장이 9일 박진...
# 1   20230109       동아일보  윤석열 대통령 부인 김건희 여사가 9일 청와대 춘추관에서 열린 국립한국문학관 특별전...
# 2   20230109       동아일보  金 “보수 근간 회복할 것”與 현역 의원 40여명 참석MB도 축전 보내 지원 사격\...
# 3   20230109       동아일보  윤석열 대통령 부인 김건희 여사가 9일 서울 종로구 청와대에서 문학 특별전시 ‘이상...
# 4   20230109       동아일보  미국 라스베이거스에서 1월 5일부터 개최된 세계 최대의 정보통신 및 가전 전시회, ...
# ..       ...        ...                                                ...
# 10  20230110       동아일보  2023 서울마라톤 참가 신청이 10일 오전 10시 시작됩니다. 풀코스 7000명,...
# 11  20230110       동아일보  국민연금 개혁과 연계해 동반인상정부, 연금 체계 전반 손보기로국민연금 재정추계 이달...
# 12  20230110       동아일보  국민의힘 지지층을 대상으로 한 당 대표 선거 여론조사에서 선두권을 달리고 있는 나경...
# 13  20230110       동아일보  국내 진보정당 간부 등이 북한의 지령을 받으며 국내 제도권 정당과 노동·시민단체 등...
# 14  20230110       동아일보  윤석열 대통령이 9일 청와대 영빈관에서 열린 보건복지부·고용노동부·여성가족부·식품의...
#
#                                               title  \
# 0            박진, 中 신임 외교부장과 첫 통화…친강 “중국발 입국자 규제 우려”
# 1                    김건희 여사 “문학이 앞서가면 미술·음악도 뒤 따라가”
# 2                        ‘인산인해’ 김기현 캠프 개소식[정치 인&아웃]
# 3           김건희 여사, 靑 근대 문학 특별전 관람…“번역·출판 지원 뒷받침해야”
# 4   [CES 2023] 브랜드 벽 허문 ‘초연결’ IoT 시대 개막, 중소기업에겐 기회?
# ..                                              ...
# 10                 [알립니다]4년만에 함께 달리는 서울마라톤, 오늘부터 접수
# 11                     공무원-사학-군인 연금도 보험료 더 내는 개혁 추진
# 12           [사설]“대출 탕감” “자기 정치”… 나경원 논란에 길 잃은 저출산委
# 13                [사설]尹 정부 첫 간첩단 사건… 엄정한 수사로 실체 밝혀야
# 14           [사설]“국민·공무원·사학연금 동시 개혁”… 실행 의지와 속도가 관건
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/020/000...
# 1   https://n.news.naver.com/mnews/article/020/000...
# 2   https://n.news.naver.com/mnews/article/020/000...
# 3   https://n.news.naver.com/mnews/article/020/000...
# 4   https://n.news.naver.com/mnews/article/020/000...
# ..                                                ...
# 10  https://n.news.naver.com/mnews/article/020/000...
# 11  https://n.news.naver.com/mnews/article/020/000...
# 12  https://n.news.naver.com/mnews/article/020/000...
# 13  https://n.news.naver.com/mnews/article/020/000...
# 14  https://n.news.naver.com/mnews/article/020/000...
#
# [486 rows x 5 columns]
